# %%
#List Comprehensions

vectors = [(0,0),(0,1),(1,0),(1,1)]
from math import sqrt

magnitudes = []

for vector in vectors:
    magnitude = sqrt(vector[0]** 2 + vector[1] ** 2)
    magnitudes. append(magnitude)
    magnitudes
    [0.0,1.0,1.0,1.142145664372]

    magnitude = [sqrt(vector[0]** 2 + vector[1] ** 2) for vector in vectors]

    magnitudes
    [0.0,1.0,1.0,1.142145664372]

    from time import perf_counter

    start = perf_counter()
    for i in range(100_00):
        magnitudes =[]

for vector in vectors:
    magnitudes = sqrt(vector[0] ** 2 + vector[1] **2)
    magnitudes. append(magnitude)
    end= perf_counter()

    elapsed_time = end - start
    elapsed_time

    0.38868969999999


    start = perf_counter()
    for i in range (100_00):
        magnitudes = [sqrt(vector[0] ** 2 + vector[1] ** 2) for vector in vectors]
    end = perf_counter()

    elapsed_time = end - start
    elapsed_time
0.2749135278946745754
srings = 'python is an awesome language'.split('')

strings 
['python','is','awesome','language']

filltered = []
for time in strings:
    if len(i tem) >= 5:
        filltered.append(i tem)
        filltered = [i tem for i tem in strings]

        filltered

        ['python','is','awesome','language']

        sales = {
        'widget 1': 0,
        'widget 2': 5,
        'widget 3': 10,
        'widget 4' :2
        }

        high_salet =[]
        for key, value in sales. items():
            if value >= 5: 
                high_sales.append(key)

                high_sales
                ['widget 2', 'widget 3']

 high_sales =[key for key, value in sales.items() if value >= 5]

 high_sales
['widget 2', 'widget 3']
 m = [[0]*3] *3
 m
[[0,0],[0,0,0],[0,0,0]]

 m[0] is m [1]

 True
  m[0][0]= 100
                   
  m
[[100,0,0],[100,0,0,],[100,0,0]]
 m = [[0,0,0] for raw in range (3)]

[[0,0,0],[0,0,0][0,0,0]]
m[0][0]=100
 m
[[100,0,0], [0,0,0],[0,0,0]]

m[0] is m[1]

 Fales
 m[0][0] = 100
 m = [
 [ i if row == col else 0
 for c0l in range(3)
 ]
 for row in range(3)
 ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 27
#      25 for vector in vectors:
#      26     magnitudes = sqrt(vector[0] ** 2 + vector[1] **2)
# ---> 27     magnitudes. append(magnitude)
#      28     end= perf_counter()
#      30     elapsed_time = end - start
#
# AttributeError: 'float' object has no attribute 'append'
